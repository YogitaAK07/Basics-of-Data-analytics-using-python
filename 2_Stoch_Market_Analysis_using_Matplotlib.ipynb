# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading data from CSV file
df=pd.read_csv('alphabet_stock_data.csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995  1105.619995
# 2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966  1120.839966
# 2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005  1097.880005
# 2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044  1186.920044
# 2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010  1186.510010
# ...                 ...          ...          ...          ...          ...
# 2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039  1428.290039
# 2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961  1444.959961
# 2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020  1464.520020
# 2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956  1469.329956
# 2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976  1469.599976
#
#              Volume
# Date
# 2020-04-01  2343100
# ...

# %%
# defining DataFrame between specific dates
range=pd.date_range(start='2020-01-20',end='2020-02-20',freq='B')
range
# Out:
# DatetimeIndex(['2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23',
#                '2020-01-24', '2020-01-27', '2020-01-28', '2020-01-29',
#                '2020-01-30', '2020-01-31', '2020-02-03', '2020-02-04',
#                '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-10',
#                '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#                '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# Q1. Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates

# %%
dff=df["2020-04-2":"2020-04-20"]

df1= pd.DataFrame(dff,columns=['Open','Close'])
df1.plot();

# %% [markdown]
# 2. Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.

# %%
ind=np.where((df.Date>='2020-04-14') & (df.Date<='2020-05-11'))
sorted=df1.iloc[ind]
sorted.plot(x='Date', y= 'Close');
xlabel=("Date")
ylabel=("Historical")

# %%
dff=df["2020-04-14":"2020-05-11"]
df2=pd.DataFrame(dff,columns=['Close'])
df2.plot()

# %% [markdown]
# Q3. Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
df1= pd.DataFrame(df,columns=['Date','Volume'])
df1.Index=df1['Date']

ind=np.where((df.Date>='2020-04-14') & (df.Date<='2020-05-11'))
sorted=df1.iloc[ind]

sorted.plot.bar();
# Out:
# <ipython-input-46-1a1b7ef15b41>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.Index=df1['Date']

# %% [markdown]
# 4. Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates

# %%
df1= pd.DataFrame(df,columns=['Date','Open','Close'])
df1.Index=df1['Date']

ind=np.where((df.Date>='2020-04-14') & (df.Date<='2020-05-11'))
sorted=df1.iloc[ind]

#sorted.plot.bar(x='Date', y='Open')
#sorted.plot.bar(x='Date', y='Close')
sorted.plot.bar()
# Out:
# <ipython-input-54-1d2895acae0e>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.Index=df1['Date']

# %% [markdown]
# 5. Write a Pandas program to create a stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df1= pd.DataFrame(df,columns=['Date','Open','Close'])
df1.Index=df1['Date']

ind=np.where((df.Date>='2020-04-14') & (df.Date<='2020-05-11'))
sorted=df1.iloc[ind]

sorted.plot.bar(stacked=True)
# Out:
# <ipython-input-55-b200dfc16746>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.Index=df1['Date']

# %% [markdown]
# 6. Write a Pandas program to create a horizontal stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df1= pd.DataFrame(df,columns=['Date','Open','Close'])
df1.Index=df1['Date']

ind=np.where((df.Date>='2020-04-14') & (df.Date<='2020-05-11'))
sorted=df1.iloc[ind]

sorted.plot.barh(stacked=True)
# Out:
# <ipython-input-56-26e4b77605cf>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.Index=df1['Date']

# %% [markdown]
# 7. Write a Pandas program to create a histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
df7=pd.DataFrame(df,columns=['Date','Open','Close','High','Low'])
df7.Index='Date'
ind=np.where((df7.Date>'2020-04-07')& (df7.Date<'2020-05-07'))
df77=df7.iloc[ind]
df77
# Out:
#           Date         Open        Close         High          Low
# 5   2020-04-08  1206.500000  1210.280029  1219.069946  1188.160034
# 6   2020-04-09  1224.079956  1211.449951  1225.569946  1196.734985
# 7   2020-04-13  1209.180054  1217.560059  1220.510010  1187.598022
# 8   2020-04-14  1245.089966  1269.229980  1282.069946  1236.930054
# 9   2020-04-15  1245.609985  1262.469971  1280.459961  1240.400024
# 10  2020-04-16  1274.099976  1263.469971  1279.000000  1242.619995
# 11  2020-04-17  1284.849976  1283.250000  1294.430054  1271.229980
# 12  2020-04-20  1271.000000  1266.609985  1281.599976  1261.369995
# 13  2020-04-21  1247.000000  1216.339966  1254.270020  1209.709961
# 14  2020-04-22  1245.540039  1263.209961  1285.613037  1242.000000
# 15  2020-04-23  1271.550049  1276.310059  1293.310059  1265.670044
# 16  2020-04-24  1261.170044  1279.310059  1280.400024  1249.449951
# 17  2020-04-27  1296.000000  1275.880005  1296.150024  1269.000000
# ...

# %%
df77.plot.hist()

# %% [markdown]
# 8. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
df7=pd.DataFrame(df,columns=['Date','Open','Close','High','Low'])
df7.Index='Date'
ind=np.where((df7.Date>'2020-04-07')& (df7.Date<'2020-05-07'))
df8=df7.iloc[ind]
df8.plot.hist(stacked=True)

# %% [markdown]
# 9. Write a Pandas program to draw a horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc. between two specific dates.

# %%
df9=pd.DataFrame(df7,columns=['Date','Open'])
df9.plot.hist(orientation='horizontal', cumulative=True)

# %% [markdown]
# 10. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates with more bins.

# %%
df7=pd.DataFrame(df,columns=['Date','Open','Close','High','Low'])
df7.Index='Date'
df7.plot.hist(bins=10,stacked=True)

# %% [markdown]
# 11. Write a Pandas program to create a stacked histograms plot with more bins of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates.

# %%
df7=pd.DataFrame(df,columns=['Date','Open','Close','High','Low'])
df7.Index='Date'
ind=np.where((df7.Date>'2020-04-07')& (df7.Date<'2020-05-07'))
df11=df7.iloc[ind]
df11.plot.hist(bins=10,stacked=True)

# %% [markdown]
# 12. Write a Pandas program to create a plot of stock price and trading volume of Alphabet Inc. between two specific dates.

# %%
df1=pd.DataFrame(df,columns=['Date','Adj Close','Volume'])
df1.Index='Date'
ind=np.where((df7.Date>'2020-04-07') & (df7.Date<'2020-05-07'))
df12=df1.iloc[ind]
df12.plot.hist(bins=10,stacked=True)

# %% [markdown]
# 13. Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. between two specific dates.

# %%
df1=pd.DataFrame(df,columns=['Date','Open','Close','High','Low','Adj Close','Volume'])
df1.Index='Date'
ind=np.where((df7.Date>'2020-04-07') & (df7.Date<'2020-05-07'))
df12=df1.iloc[ind]
df12.plot(subplots = True)
plt.show()

# %% [markdown]
# 14. Write a Pandas program to create a plot of adjusted closing prices, thirty days and forty days simple moving average of Alphabet Inc. between two specific dates.

# %% [markdown]
# A simple moving average (SMA) is an arithmetic moving average calculated by adding recent prices and then dividing that figure by the number of time periods in the calculation average. For example, one could add the closing price of a security for a number of time periods and then divide this total by that same number of periods. Short-term averages respond quickly to changes in the price of the underlying security, while long-term averages are slower to react.

# %%
df1=pd.DataFrame(df,columns=['Date','Open','Close','High','Low','Adj Close','Volume'])
df1.Index='Date'
ind=np.where((df7.Date>'2020-04-07') & (df7.Date<'2021-05-07'))
df12=df1.iloc[ind]

df12['SMA_30_days'] = df12.iloc[:,5].rolling(window=30).mean() 
df12['SMA_40_days'] = df12.iloc[:,5].rolling(window=40).mean()
plt.grid(True)

plt.plot(df12['Adj Close'],label='Adjusted Closing Price', color='black')
plt.plot(df12['SMA_30_days'],label='30 days simple moving average', color='red')
plt.plot(df12['SMA_40_days'],label='40 days simple moving average', color='green')

df12.plot(subplots = True)
plt.show()
# Out:
# <ipython-input-50-569aee2b1777>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['SMA_30_days'] = df12.iloc[:,5].rolling(window=30).mean()
# <ipython-input-50-569aee2b1777>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['SMA_40_days'] = df12.iloc[:,5].rolling(window=40).mean()

# %% [markdown]
# 15. Write a Pandas program to create a plot of adjusted closing prices, 30 days simple moving average and exponential moving average of Alphabet Inc. between two specific dates.

# %% [markdown]
# What is Simple Moving Average (SMA)?
# In financial applications a simple moving average (SMA) is the unweighted mean of the previous n data. However, in science and engineering, the mean is normally taken from an equal number of data on either side of a central value. This ensures that variations in the mean are aligned with the variations in the data rather than being shifted in time.
#
# What Is an Exponential Moving Average (EMA)?
# From investopedia.com - An exponential moving average (EMA) is a type of moving average (MA) that places a greater weight and significance on the most recent data points. The exponential moving average is also referred to as the exponentially weighted moving average. An exponentially weighted moving average reacts more significantly to recent price changes than a simple moving average (SMA), which applies an equal weight to all observations in the period.

# %%
df1=pd.DataFrame(df,columns=['Date','Open','Close','High','Low','Adj Close','Volume'])
df1.Index='Date'
ind=np.where((df1.Date>'2020-04-07') & (df1.Date<'2020-12-07'))
df15=df1.iloc[ind]

df15['SMA_30_days'] = df15.iloc[:,5].rolling(window=30).mean() 
df15['EMA_20_days'] = df15.iloc[:,5].ewm(span=20,adjust=False).mean()
plt.figure(figsize=[15,10])
plt.grid(True)

plt.plot(df15['Adj Close'],label='Adjusted Closing Price', color='black')
plt.plot(df15['SMA_30_days'],label='30 days Simple moving average', color='red')
plt.plot(df15['EMA_20_days'],label='20 days Exponential moving average', color='green')
plt.legend(loc=2)
plt.show()
# Out:
# <ipython-input-20-64063b11e30c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df15['SMA_30_days'] = df15.iloc[:,5].rolling(window=30).mean()
# <ipython-input-20-64063b11e30c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df15['EMA_20_days'] = df15.iloc[:,5].ewm(span=20,adjust=False).mean()

# %%
df1=pd.DataFrame(df,columns=['Date','Open','Close','High','Low','Adj Close','Volume'])
df1.Index='Date'
ind=np.where((df1.Date>'2020-04-07') & (df1.Date<'2021-12-07'))
df15=df1.iloc[ind]
df_30MA['B']=df15.Close.rolling(30).mean()
df_30MA['A']=df15.Close.rolling(20).mean()
plt.plot(df_30MA['B'])
plt.plot(df_30MA['A'])
plt.plot(df15['Close'])

# %% [markdown]
# 16.
# Write a Pandas program to create a scatter plot of the trading volume/stock prices of Alphabet Inc. stock between two specific dates.

# %%
df1=pd.DataFrame(df,columns=['Date','Adj Close','Volume'])
df1.Index='Date'
ind=np.where((df7.Date>'2020-04-07') & (df7.Date<'2020-07-07'))
df15=df1.iloc[ind]
df15.plot.scatter(x='Adj Close',y='Volume')

# %% [markdown]
# 17. Write a Pandas program to create a plot to visualize daily percentage returns of Alphabet Inc. stock price between two specific dates.

# %%
df1=pd.DataFrame(df,columns=['Date','Adj Close'])
df1.Index='Date'
ind=np.where((df7.Date>'2020-07-01') & (df7.Date<'2020-09-07'))
df17=df1.iloc[ind]
df17.plot(marker='*')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
